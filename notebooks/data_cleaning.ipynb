# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Import Relevant Packages and Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandoc

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Import the data

# %%
# read in the data
df_insta = pd.read_csv('../data/raw/Post Performance (Stanbic IBTC) January 1, 2013 - July 13, 2023_Instagram.csv')
df_lnkd = pd.read_csv('../data/raw/Post Performance (Stanbic IBTC) January 1, 2013 - July 13, 2023_Linkedin.csv')
df_twit = pd.read_csv('../data/raw/Post Performance (Stanbic IBTC) January 1, 2013 - July 13, 2023_Twitter.csv')
df_fbk = pd.read_csv('../data/raw/Post Performance (Stanbic IBTC) January 1, 2013 - July 13, 2023_Facebook.csv')
# Out:
# C:\Users\Victor Essien\AppData\Local\Temp\ipykernel_2536\2350594635.py:2: DtypeWarning: Columns (21,22,30,31,32,33,40,78,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_insta = pd.read_csv('../data/raw/Post Performance (Stanbic IBTC) January 1, 2013 - July 13, 2023_Instagram.csv')
# C:\Users\Victor Essien\AppData\Local\Temp\ipykernel_2536\2350594635.py:3: DtypeWarning: Columns (78,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_lnkd = pd.read_csv('../data/raw/Post Performance (Stanbic IBTC) January 1, 2013 - July 13, 2023_Linkedin.csv')
# C:\Users\Victor Essien\AppData\Local\Temp\ipykernel_2536\2350594635.py:4: DtypeWarning: Columns (32,33,41,53,61,78,146) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_twit = pd.read_csv('../data/raw/Post Performance (Stanbic IBTC) January 1, 2013 - July 13, 2023_Twitter.csv')
# C:\Users\Victor Essien\AppData\Local\Temp\ipykernel_2536\2350594635.py:5: DtypeWarning: Columns (10,11,12,13,15,16,18,19,21,22,23,24,26,45,46,51,52,62,63,64,65,69,71,73,78,80,82,83,85,93,95,97,98,99,100,102,104,105,106,108,110,111,113,115,116,117,118,119,121,122,123) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_fbk = pd.read_csv('../data/raw/Post Performance (Stanbic IBTC) January 1, 2013 - July 13, 2023_Facebook.csv')

# %% [markdown]
# ## First Look

# %%
# function to get the shape of all dataframes
def get_shape(*dataframes):
    for idx, df in enumerate(dataframes, start=1):
        print(f"Shape of {df['Network'].values[0]} dataset: {df.shape}")

# %%
get_shape(df_insta, df_lnkd, df_twit, df_fbk)
# Out:
# Shape of Instagram dataset: (10000, 147)
# Shape of LinkedIn dataset: (7760, 147)
# Shape of Twitter dataset: (8529, 147)
# Shape of Facebook dataset: (9803, 147)

# %% [markdown]
# They all have the same number of columns, but are they the same?

# %%
# check if all dataframes have the same columns
if list(df_insta.columns) == list(df_twit.columns) == list(df_lnkd.columns) == list(df_fbk.columns):
   print('True')
else: 
    print('False')
# Out:
# True

# %% [markdown]
# Since they all have the same columns, a function will be needed to clean all of them. Before that the columns need to be investigated to determine what impurities or inconsistencies exist within the data, so as to inform cleaning steps.

# %% [markdown]
# ## Cleaning

# %% [markdown]
# To clean all dataframes without concatenating them, I create a test dataframe, scope the columns for impurities and inconsistencies then define a function to generalize to the four dataframes.

# %% [markdown]
# ### Defining the cleaning process:
# - Standardize column names
# - Set appropriate data types
# - Check for general inconsistencies
# - Check for and deal with missing values
# - Remove duplicates
# - Remove excessive whitespace from string columns
# - Define function and Save clean data to a csv file

# %% [markdown]
# #### Standardize column names

# %%
# make a copy of one dataset
df_test = df_insta.copy()

# %%
# view columns
df_test.columns
# Out:
# Index(['Date', 'Post ID', 'Network', 'Post Type', 'Content Type', 'Profile',
#        'Sent by', 'Link', 'Post', 'Linked Content',
#        ...
#        'Video Removed from Playlists', 'Annotation Impressions',
#        'Annotation Clickable Impressions', 'Annotation Closable Impressions',
#        'Annotation Closes', 'Card Impressions', 'Card Teaser Impressions',
#        'Card Teaser Clicks', 'Poll Votes', 'Tags'],
#       dtype='object', length=147)

# %%
# replace spaces and special character with '_'
df_test.columns = df_test.columns.str.lower().str.replace('-', '_').str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

# %% [markdown]
# #### Set appropriate data types

# %% [markdown]
# To do this, the columns need to be checked to understand why pandas could not define their data types on import or what data types are mixed within such columns.

# %%
df_test.dtypes
# Out:
# date                        object
# post_id                      int64
# network                     object
# post_type                   object
# content_type                object
#                             ...
# card_impressions           float64
# card_teaser_impressions    float64
# card_teaser_clicks         float64
# poll_votes                 float64
# tags                        object
# Length: 147, dtype: object

# %% [markdown]
# From the output above of the data types of each column, it can be seen already that some columns dont have the correct data type. This may be due to inconsistencies of the data within those columns. So those columns need to be cleaned and set to the appropriate data type. An example is the date column.

# %% [markdown]
# A further look can be had at the data type of the first 20 columns below:

# %%
df_test.dtypes[:20]
# Out:
# date                            object
# post_id                          int64
# network                         object
# post_type                       object
# content_type                    object
# profile                         object
# sent_by                         object
# link                            object
# post                            object
# linked_content                 float64
# impressions                     object
# organic_impressions             object
# viral_impressions              float64
# non_viral_impressions          float64
# paid_impressions               float64
# fan_impressions                float64
# fan_organic_impressions        float64
# fan_paid_impressions           float64
# non_fan_impressions            float64
# non_fan_organic_impressions    float64
# dtype: object

# %% [markdown]
# The impressions columns should contain only numbers.

# %%
 # convert date column to datetime
df_test['date'] = pd.to_datetime(df_test['date'], format='%m/%d/%Y %I:%M %p')
       
# convert string columns with numbers to float
for column in df_test.columns:
    if df_test[column].dtype == 'object':
        if df_test[column].str.isnumeric().any():
            df_test[column] = df_test[column].str.replace(',','').astype(float)
        elif 'per' in df_test[column].name:
            df_test[column] = df_test[column].str.replace(',','').str.replace('%','').astype(float)

# %%
# check to confirm 
df_test.dtypes[:20]
# Out:
# date                           datetime64[ns]
# post_id                                 int64
# network                                object
# post_type                              object
# content_type                           object
# profile                                object
# sent_by                                object
# link                                   object
# post                                   object
# linked_content                        float64
# impressions                           float64
# organic_impressions                   float64
# viral_impressions                     float64
# non_viral_impressions                 float64
# paid_impressions                      float64
# fan_impressions                       float64
# fan_organic_impressions               float64
# fan_paid_impressions                  float64
# non_fan_impressions                   float64
# non_fan_organic_impressions           float64
# dtype: object

# %% [markdown]
# #### Check for general inconsistencies

# %% [markdown]
# While scoping some of the categorical columns, something curious was discovered. See below:

# %%
df_test.sent_by.value_counts()
# Out:
# sent_by
#                      4967
# Blessing Ubah        2707
# Aramide Salami       1733
# Kemi Amoo             315
# Sophia Amuka          192
# Damilare Oyekanmi      86
# Name: count, dtype: int64

# %% [markdown]
# There are 4967 post made by ' '. There are too many rows to just drop and those rows contain important data from which insights can be extracted. The best thing is to replace that white space with 'admin'. The reasoning is someone was making those posts on behalf of the profile.

# %%
# replace white space in sent_by with admin
df_test['sent_by'] = df_test['sent_by'].replace(' ', 'admin')

# %%
# to confirm
df_test.sent_by.value_counts()
# Out:
# sent_by
# admin                4967
# Blessing Ubah        2707
# Aramide Salami       1733
# Kemi Amoo             315
# Sophia Amuka          192
# Damilare Oyekanmi      86
# Name: count, dtype: int64

# %% [markdown]
# #### Check for and deal with missing values

# %%
# check percentage of missing values per column
missing_percentage = df_test.isnull().sum()/len(df_test)*100
missing_types = df_test.dtypes
missing_values = pd.DataFrame({'missing_percentage' : missing_percentage, 'dtype' : missing_types})

# %%
# missing_values.missing_percentage *10000
missing_values[:20]
# Out:
#                              missing_percentage           dtype
# date                                       0.00  datetime64[ns]
# post_id                                    0.00           int64
# network                                    0.00          object
# post_type                                  0.00          object
# content_type                               0.00          object
# profile                                    0.00          object
# sent_by                                    0.00          object
# link                                       0.00          object
# post                                       0.11          object
# linked_content                           100.00         float64
# impressions                               14.84         float64
# organic_impressions                       14.84         float64
# viral_impressions                        100.00         float64
# non_viral_impressions                    100.00         float64
# paid_impressions                         100.00         float64
# fan_impressions                          100.00         float64
# fan_organic_impressions                  100.00         float64
# fan_paid_impressions                     100.00         float64
# non_fan_impressions                      100.00         float64
# non_fan_organic_impressions              100.00         float64

# %%
df_test[df_test.post.isnull()]
# Out:
#                     date            post_id    network post_type content_type  \
# 1423 2021-10-06 15:18:00  18264735889006746  Instagram      Post        Video
# 2687 2022-11-07 15:15:00  17996455921508611  Instagram      Post        Video
# 3037 2021-06-02 14:36:00  17928942340583441  Instagram      Post        Video
# 3466 2019-11-10 10:22:00  18075127972178513  Instagram      Post        Photo
# 4057 2021-08-05 14:36:00  17877664865423804  Instagram      Post        Video
# 4680 2021-12-08 14:55:00  17947547986621047  Instagram      Post        Video
# 4721 2021-11-10 14:43:00  17916752206969560  Instagram      Post        Video
# 4881 2021-12-17 15:39:00  17955736783523769  Instagram      Post        Video
# 5297 2021-12-17 15:33:00  18119747119255695  Instagram      Post        Video
# 8542 2022-07-08 10:05:00  17937413156227992  Instagram      Post     Carousel
# 9343 2015-12-02 20:50:00  17843461603092131  Instagram      Post        Video
#
#           profile       sent_by                                       link  \
# 1423  stanbicibtc         admin  https://www.instagram.com/tv/CUsLOdsoeK7/
# 2687  stanbicibtc         admin  https://www.instagram.com/tv/Ckqad7iI4Lx/
# 3037  stanbicibtc         admin  https://www.instagram.com/tv/CPnqTksg0xY/
# 3466  stanbicibtc         admin   https://www.instagram.com/p/B4rgFtLFS0Y/
# 4057  stanbicibtc         admin  https://www.instagram.com/tv/CSMdKslodw-/
# 4680  stanbicibtc         admin  https://www.instagram.com/tv/CXOWnewoDbO/
# 4721  stanbicibtc         admin  https://www.instagram.com/tv/CWGPHnaIN6D/
# 4881  stanbicibtc         admin  https://www.instagram.com/tv/CXlm5xEoRdP/
# 5297  stanbicibtc         admin  https://www.instagram.com/tv/CXlmQIroVuz/
# 8542  stanbicibtc  Sophia Amuka   https://www.instagram.com/p/CfvuCJTsCuV/
# 9343  stanbicibtc         admin    https://www.instagram.com/p/-zUIMjyvZ1/
#
#      post  linked_content  impressions  organic_impressions  \
# 1423  NaN             NaN       3024.0               3024.0
# 2687  NaN             NaN       2195.0               2195.0
# 3037  NaN             NaN       2051.0               2051.0
# 3466  NaN             NaN       1823.0               1823.0
# 4057  NaN             NaN       1469.0               1469.0
# 4680  NaN             NaN       1193.0               1193.0
# 4721  NaN             NaN       1249.0               1249.0
# 4881  NaN             NaN       1104.0               1104.0
# 5297  NaN             NaN        883.0                883.0
# 8542  NaN             NaN          NaN                  NaN
# 9343  NaN             NaN          NaN                  NaN
#
#       viral_impressions  non_viral_impressions  paid_impressions  \
# 1423                NaN                    NaN               NaN
# 2687                NaN                    NaN               NaN
# 3037                NaN                    NaN               NaN
# 3466                NaN                    NaN               NaN
# 4057                NaN                    NaN               NaN
# 4680                NaN                    NaN               NaN
# 4721                NaN                    NaN               NaN
# 4881                NaN                    NaN               NaN
# 5297                NaN                    NaN               NaN
# 8542                NaN                    NaN               NaN
# 9343                NaN                    NaN               NaN
#
#       fan_impressions  fan_organic_impressions  fan_paid_impressions  \
# 1423              NaN                      NaN                   NaN
# 2687              NaN                      NaN                   NaN
# 3037              NaN                      NaN                   NaN
# 3466              NaN                      NaN                   NaN
# 4057              NaN                      NaN                   NaN
# 4680              NaN                      NaN                   NaN
# 4721              NaN                      NaN                   NaN
# 4881              NaN                      NaN                   NaN
# 5297              NaN                      NaN                   NaN
# 8542              NaN                      NaN                   NaN
# 9343              NaN                      NaN                   NaN
#
#       non_fan_impressions  non_fan_organic_impressions  \
# 1423                  NaN                          NaN
# 2687                  NaN                          NaN
# 3037                  NaN                          NaN
# 3466                  NaN                          NaN
# 4057                  NaN                          NaN
# 4680                  NaN                          NaN
# 4721                  NaN                          NaN
# 4881                  NaN                          NaN
# 5297                  NaN                          NaN
# 8542                  NaN                          NaN
# 9343                  NaN                          NaN
#
#       non_fan_paid_impressions   reach  organic_reach  viral_reach  \
# 1423                       NaN  2681.0         2681.0          NaN
# 2687                       NaN  1982.0         1982.0          NaN
# 3037                       NaN  1811.0         1811.0          NaN
# 3466                       NaN  1617.0         1617.0          NaN
# 4057                       NaN  1353.0         1353.0          NaN
# 4680                       NaN  1098.0         1098.0          NaN
# 4721                       NaN  1081.0         1081.0          NaN
# 4881                       NaN  1013.0         1013.0          NaN
# 5297                       NaN   804.0          804.0          NaN
# 8542                       NaN     NaN            NaN          NaN
# 9343                       NaN     NaN            NaN          NaN
#
#       non_viral_reach  paid_reach  fan_reach  fan_paid_reach  potential_reach  \
# 1423              NaN         NaN        NaN             NaN              NaN
# 2687              NaN         NaN        NaN             NaN              NaN
# 3037              NaN         NaN        NaN             NaN              NaN
# 3466              NaN         NaN        NaN             NaN              NaN
# 4057              NaN         NaN        NaN             NaN              NaN
# 4680              NaN         NaN        NaN             NaN              NaN
# 4721              NaN         NaN        NaN             NaN              NaN
# 4881              NaN         NaN        NaN             NaN              NaN
# 5297              NaN         NaN        NaN             NaN              NaN
# 8542              NaN         NaN        NaN             NaN              NaN
# 9343              NaN         NaN        NaN             NaN              NaN
#
#       engagement_rate_per_impression  engagement_rate_per_reach  engagements  \
# 1423                            3.31                       3.73        100.0
# 2687                            3.51                       3.88         77.0
# 3037                            4.00                       4.53         82.0
# 3466                            2.80                       3.15         51.0
# 4057                            3.06                       3.33         45.0
# 4680                            4.11                       4.46         49.0
# 4721                            5.36                       6.20         67.0
# 4881                            2.81                       3.06         31.0
# 5297                            2.04                       2.24         18.0
# 8542                             NaN                        NaN          NaN
# 9343                             NaN                        NaN          NaN
#
#       reactions  likes  dislikes  love_reactions  haha_reactions  \
# 1423       82.0   82.0       NaN             NaN             NaN
# 2687       63.0   63.0       NaN             NaN             NaN
# 3037       73.0   73.0       NaN             NaN             NaN
# 3466       48.0   48.0       NaN             NaN             NaN
# 4057       36.0   36.0       NaN             NaN             NaN
# 4680       46.0   46.0       NaN             NaN             NaN
# 4721       49.0   49.0       NaN             NaN             NaN
# 4881       30.0   30.0       NaN             NaN             NaN
# 5297       18.0   18.0       NaN             NaN             NaN
# 8542        NaN    NaN       NaN             NaN             NaN
# 9343        NaN    NaN       NaN             NaN             NaN
#
#       wow_reactions  sad_reactions  angry_reactions  comments  shares  saves  \
# 1423            NaN            NaN              NaN      16.0     NaN    2.0
# 2687            NaN            NaN              NaN      12.0     NaN    2.0
# 3037            NaN            NaN              NaN       5.0     NaN    4.0
# 3466            NaN            NaN              NaN       2.0     NaN    1.0
# 4057            NaN            NaN              NaN       7.0     NaN    2.0
# 4680            NaN            NaN              NaN       NaN     NaN    0.0
# 4721            NaN            NaN              NaN       NaN     NaN    2.0
# 4881            NaN            NaN              NaN       NaN     NaN    1.0
# 5297            NaN            NaN              NaN       NaN     NaN    0.0
# 8542            NaN            NaN              NaN       NaN     NaN    NaN
# 9343            NaN            NaN              NaN       NaN     NaN    NaN
#
#       click_through_rate  post_link_clicks  other_post_clicks  \
# 1423                 NaN               NaN                NaN
# 2687                 NaN               NaN                NaN
# 3037                 NaN               NaN                NaN
# 3466                 NaN               NaN                NaN
# 4057                 NaN               NaN                NaN
# 4680                 NaN               NaN                NaN
# 4721                 NaN               NaN                NaN
# 4881                 NaN               NaN                NaN
# 5297                 NaN               NaN                NaN
# 8542                 NaN               NaN                NaN
# 9343                 NaN               NaN                NaN
#
#       post_clicks_all  post_media_clicks  post_hashtag_clicks  \
# 1423              NaN                NaN                  NaN
# 2687              NaN                NaN                  NaN
# 3037              NaN                NaN                  NaN
# 3466              NaN                NaN                  NaN
# 4057              NaN                NaN                  NaN
# 4680              NaN                NaN                  NaN
# 4721              NaN                NaN                  NaN
# 4881              NaN                NaN                  NaN
# 5297              NaN                NaN                  NaN
# 8542              NaN                NaN                  NaN
# 9343              NaN                NaN                  NaN
#
#       post_detail_expand_clicks  profile_clicks  post_photo_view_clicks  \
# 1423                        NaN             NaN                     NaN
# 2687                        NaN             NaN                     NaN
# 3037                        NaN             NaN                     NaN
# 3466                        NaN             NaN                     NaN
# 4057                        NaN             NaN                     NaN
# 4721                           NaN                                NaN
# 4881                           NaN                                NaN
# 5297                           NaN                                NaN
# 8542                           NaN                                NaN
# 9343                           NaN                                NaN
#
#       autoplay_full_video_views  click_to_play_full_video_views  \
# 1423                        NaN                             NaN
# 2687                        NaN                             NaN
# 3037                        NaN                             NaN
# 3466                        NaN                             NaN
# 4057                        NaN                             NaN
# 4680                        NaN                             NaN
# 4721                        NaN                             NaN
# 4881                        NaN                             NaN
# 5297                        NaN                             NaN
# 8542                        NaN                             NaN
# 9343                        NaN                             NaN
#
#       95%_video_views  organic_95%_video_views  paid_95%_video_views  \
# 1423              NaN                      NaN                   NaN
# 2687              NaN                      NaN                   NaN
# 3037              NaN                      NaN                   NaN
# 3466              NaN                      NaN                   NaN
# 4057              NaN                      NaN                   NaN
# 4680              NaN                      NaN                   NaN
# 4721              NaN                      NaN                   NaN
# 4881              NaN                      NaN                   NaN
# 5297              NaN                      NaN                   NaN
# 8542              NaN                      NaN                   NaN
# 9343              NaN                      NaN                   NaN
#
#       video_length_seconds  average_video_time_watched_seconds  \
# 1423                   NaN                                 NaN
# 2687                   NaN                                 NaN
# 3037                   NaN                                 NaN
# 3466                   NaN                                 NaN
# 4057                   NaN                                 NaN
# 4680                   NaN                                 NaN
# 4721                   NaN                                 NaN
# 4881                   NaN                                 NaN
# 5297                   NaN                                 NaN
# 8542                   NaN                                 NaN
# 9343                   NaN                                 NaN
#
#       video_view_time_seconds  organic_video_view_time_seconds  \
# 1423                      NaN                              NaN
# 2687                      NaN                              NaN
# 3037                      NaN                              NaN
# 3466                      NaN                              NaN
# 4057                      NaN                              NaN
# 4680                      NaN                              NaN
# 4721                      NaN                              NaN
# 4881                      NaN                              NaN
# 5297                      NaN                              NaN
# 8542                      NaN                              NaN
# 9343                      NaN                              NaN
#
#       paid_video_view_time_seconds  unique_video_views  \
# 1423                           NaN                 NaN
# 2687                           NaN                 NaN
# 3037                           NaN                 NaN
# 3466                           NaN                 NaN
# 4057                           NaN                 NaN
# 4680                           NaN                 NaN
# 4721                           NaN                 NaN
# 4881                           NaN                 NaN
# 5297                           NaN                 NaN
# 8542                           NaN                 NaN
# 9343                           NaN                 NaN
#
#       unique_organic_video_views  unique_paid_video_views  \
# 1423                         NaN                      NaN
# 2687                         NaN                      NaN
# 3037                         NaN                      NaN
# 3466                         NaN                      NaN
# 4057                         NaN                      NaN
# 4680                         NaN                      NaN
# 4721                         NaN                      NaN
# 4881                         NaN                      NaN
# 5297                         NaN                      NaN
# 8542                         NaN                      NaN
# 9343                         NaN                      NaN
#
#       unique_10_second_video_views  unique_full_video_views  \
# 1423                           NaN                      NaN
# 2687                           NaN                      NaN
# 3037                           NaN                      NaN
# 3466                           NaN                      NaN
# 4057                           NaN                      NaN
# 4680                           NaN                      NaN
# 4721                           NaN                      NaN
# 4881                           NaN                      NaN
# 5297                           NaN                      NaN
# 8542                           NaN                      NaN
# 9343                           NaN                      NaN
#
#       unique_organic_95%_video_views  unique_paid_95%_video_views  \
# 1423                             NaN                          NaN
# 2687                             NaN                          NaN
# 5297                               NaN                              NaN
# 8542                               NaN                              NaN
# 9343                               NaN                              NaN
#
#       annotation_closes  card_impressions  card_teaser_impressions  \
# 1423                NaN               NaN                      NaN
# 2687                NaN               NaN                      NaN
# 3037                NaN               NaN                      NaN
# 3466                NaN               NaN                      NaN
# 4057                NaN               NaN                      NaN
# 4680                NaN               NaN                      NaN
# 4721                NaN               NaN                      NaN
# 4881                NaN               NaN                      NaN
# 5297                NaN               NaN                      NaN
# 8542                NaN               NaN                      NaN
# 9343                NaN               NaN                      NaN
#
#       card_teaser_clicks  poll_votes           tags
# 1423                 NaN         NaN  Reward4Saving
# 2687                 NaN         NaN            NaN
# 3037                 NaN         NaN            NaN
# 3466                 NaN         NaN            NaN
# 4057                 NaN         NaN            NaN
# 4680                 NaN         NaN  Reward4Saving
# 4721                 NaN         NaN  Reward4Saving
# 4881                 NaN         NaN  Reward4Saving
# 5297                 NaN         NaN  Reward4Saving
# 8542                 NaN         NaN            NaN
# 9343                 NaN         NaN            NaN

# %%
df_test[df_test.impressions.isnull()]
# Out:
#                     date            post_id    network post_type content_type  \
# 8516 2023-06-12 13:08:00  18029321227525834  Instagram      Post     Carousel
# 8517 2023-06-08 09:55:00  18365455210048288  Instagram      Post        Photo
# 8518 2023-06-07 13:30:00  17964499847327992  Instagram      Post        Photo
# 8519 2023-05-16 20:30:00  18005669605736790  Instagram      Post        Photo
# 8520 2023-04-27 20:18:00  17979979232158293  Instagram      Post        Photo
# ...                  ...                ...        ...       ...          ...
# 9995 2014-12-24 17:37:00  17841808444024797  Instagram      Post        Photo
# 9996 2014-12-24 10:28:00  17841674617024797  Instagram      Post        Photo
# 9997 2014-12-23 17:14:00  17842896850024797  Instagram      Post        Photo
# 9998 2014-12-23 10:38:00  17841674620024797  Instagram      Post        Photo
# 9999 2014-12-22 17:59:00  17841808438024797  Instagram      Post        Photo
#
#           profile        sent_by                                      link  \
# 8516  stanbicibtc  Blessing Ubah  https://www.instagram.com/p/CtY8c1Ts0pP/
# 8517  stanbicibtc  Blessing Ubah  https://www.instagram.com/p/CtOTPwcMPZ-/
# 8518  stanbicibtc      Kemi Amoo  https://www.instagram.com/p/CtMG-nLOyVP/
# 8519  stanbicibtc      Kemi Amoo  https://www.instagram.com/p/CsUNo24OrlI/
# 8520  stanbicibtc   Sophia Amuka  https://www.instagram.com/p/CrjRFyLByBP/
# ...           ...            ...                                       ...
# 9995  stanbicibtc          admin   https://www.instagram.com/p/w_xUG5yvRB/
# 9996  stanbicibtc          admin   https://www.instagram.com/p/w_AUutyvQD/
# 9997  stanbicibtc          admin   https://www.instagram.com/p/w9J5vpyvY4/
# 9998  stanbicibtc          admin   https://www.instagram.com/p/w8cnwpSvY5/
# 9999  stanbicibtc          admin   https://www.instagram.com/p/w6qRb-yvai/
#
#                                                    post  linked_content  \
# 8516  At Stanbic IBTC, we hold special gatherings fo...             NaN
# 8517  Motor insurance is required for any ‘Idan’ who...             NaN
# 8518  Did you know that you can use your retirement ...             NaN
# 8519  We celebrate the boy child today and every day...             NaN
# 8520  Make your money bloom with the right investmen...             NaN
# ...                                                 ...             ...
# 9995  Withdraw cash up to 5 times, pay bills or tran...             NaN
# 9996  #CardDiaries week 13\n\nI love Christmas! In m...             NaN
# 9997  Eat-in this holidays. \nInstead of going out t...             NaN
# 9998  If you do not move forward, you will always be...             NaN
# 9999  Travel to Dubai this season with #StanbicDelig...             NaN
#
#       impressions  organic_impressions  viral_impressions  \
# 8516          NaN                  NaN                NaN
# 8517          NaN                  NaN                NaN
# 8518          NaN                  NaN                NaN
# 8519          NaN                  NaN                NaN
# 8520          NaN                  NaN                NaN
# ...           ...                  ...                ...
# 9995          NaN                  NaN                NaN
# 9996          NaN                  NaN                NaN
# 9997          NaN                  NaN                NaN
# 9998          NaN                  NaN                NaN
# 9999          NaN                  NaN                NaN
#
#       non_viral_impressions  paid_impressions  fan_impressions  \
# 8516                    NaN               NaN              NaN
# 8517                    NaN               NaN              NaN
# 8518                    NaN               NaN              NaN
# 8519                    NaN               NaN              NaN
# 8520                    NaN               NaN              NaN
# ...                     ...               ...              ...
# 9995                    NaN               NaN              NaN
# 9996                    NaN               NaN              NaN
# 9997                    NaN               NaN              NaN
# 9998                    NaN               NaN              NaN
# 9999                    NaN               NaN              NaN
#
#       fan_organic_impressions  fan_paid_impressions  non_fan_impressions  \
# 8516                      NaN                   NaN                  NaN
# 8517                      NaN                   NaN                  NaN
# 8518                      NaN                   NaN                  NaN
# 8519                      NaN                   NaN                  NaN
# 8520                      NaN                   NaN                  NaN
# ...                       ...                   ...                  ...
# 9995                      NaN                   NaN                  NaN
# 9996                      NaN                   NaN                  NaN
# 9997                      NaN                   NaN                  NaN
# 9998                      NaN                   NaN                  NaN
# 9999                      NaN                   NaN                  NaN
#
#       non_fan_organic_impressions  non_fan_paid_impressions  reach  \
# 8516                          NaN                       NaN    NaN
# 8517                          NaN                       NaN    NaN
# 8518                          NaN                       NaN    NaN
# 8519                          NaN                       NaN    NaN
# 8520                          NaN                       NaN    NaN
# ...                           ...                       ...    ...
# 9995                          NaN                       NaN    NaN
# 9996                          NaN                       NaN    NaN
# 9997                          NaN                       NaN    NaN
# 9998                          NaN                       NaN    NaN
# 9999                          NaN                       NaN    NaN
#
#       organic_reach  viral_reach  non_viral_reach  paid_reach  fan_reach  \
# 8516            NaN          NaN              NaN         NaN        NaN
# 8517            NaN          NaN              NaN         NaN        NaN
# 8518            NaN          NaN              NaN         NaN        NaN
# 8519            NaN          NaN              NaN         NaN        NaN
# 8520            NaN          NaN              NaN         NaN        NaN
# ...             ...          ...              ...         ...        ...
# 9995            NaN          NaN              NaN         NaN        NaN
# 9996            NaN          NaN              NaN         NaN        NaN
# 9997            NaN          NaN              NaN         NaN        NaN
# 9998            NaN          NaN              NaN         NaN        NaN
# 9999            NaN          NaN              NaN         NaN        NaN
#
#       fan_paid_reach  potential_reach  engagement_rate_per_impression  \
# 8516             NaN              NaN                             NaN
# 8517             NaN              NaN                             NaN
# 8518             NaN              NaN                             NaN
# 8519             NaN              NaN                             NaN
# 8520             NaN              NaN                             NaN
# ...              ...              ...                             ...
# 9995             NaN              NaN                             NaN
# 9996             NaN              NaN                             NaN
# 9997             NaN              NaN                             NaN
# 9998             NaN              NaN                             NaN
# 9999             NaN              NaN                             NaN
#
#       engagement_rate_per_reach  engagements  reactions  likes  dislikes  \
# 8516                        NaN          NaN        NaN    NaN       NaN
# 8517                        NaN          NaN        NaN    NaN       NaN
# 8518                        NaN          NaN        NaN    NaN       NaN
# 8519                        NaN          NaN        NaN    NaN       NaN
# 8520                        NaN          NaN        NaN    NaN       NaN
# ...                         ...          ...        ...    ...       ...
# 9995                        NaN          NaN        NaN    NaN       NaN
# 9996                        NaN          NaN        NaN    NaN       NaN
# 9997                        NaN          NaN        NaN    NaN       NaN
# 9998                        NaN          NaN        NaN    NaN       NaN
# 9999                        NaN          NaN        NaN    NaN       NaN
#
#       love_reactions  haha_reactions  wow_reactions  sad_reactions  \
# 8516             NaN             NaN            NaN            NaN
# 8517             NaN             NaN            NaN            NaN
# 8518             NaN             NaN            NaN            NaN
# 8519             NaN             NaN            NaN            NaN
# 8520             NaN             NaN            NaN            NaN
# ...              ...             ...            ...            ...
# 9995             NaN             NaN            NaN            NaN
# 9996             NaN             NaN            NaN            NaN
# 9997             NaN             NaN            NaN            NaN
# 9998             NaN             NaN            NaN            NaN
# 9999             NaN             NaN            NaN            NaN
#
#       angry_reactions  comments  shares  saves  click_through_rate  \
# 8516              NaN       NaN     NaN    NaN                 NaN
# 8517              NaN       NaN     NaN    NaN                 NaN
# 8518              NaN       NaN     NaN    NaN                 NaN
# 8519              NaN       NaN     NaN    NaN                 NaN
# 8520              NaN       NaN     NaN    NaN                 NaN
# ...               ...       ...     ...    ...                 ...
# 9995              NaN       NaN     NaN    NaN                 NaN
# 9996              NaN       NaN     NaN    NaN                 NaN
# 9997              NaN       NaN     NaN    NaN                 NaN
# 9998              NaN       NaN     NaN    NaN                 NaN
# 9999              NaN       NaN     NaN    NaN                 NaN
#
#       post_link_clicks  other_post_clicks  post_clicks_all  post_media_clicks  \
# 8516               NaN                NaN              NaN                NaN
# 8517               NaN                NaN              NaN                NaN
# 8518               NaN                NaN              NaN                NaN
# 8519               NaN                NaN              NaN                NaN
# 8520               NaN                NaN              NaN                NaN
# ...                ...                ...              ...                ...
# 9995               NaN                NaN              NaN                NaN
# 9996               NaN                NaN              NaN                NaN
# 9997               NaN                NaN              NaN                NaN
# 9998               NaN                NaN              NaN                NaN
# 9999               NaN                NaN              NaN                NaN
#
#       post_hashtag_clicks  post_detail_expand_clicks  profile_clicks  \
# 8516                  NaN                        NaN             NaN
# 8517                  NaN                        NaN             NaN
# 8518                  NaN                        NaN             NaN
# 8519                  NaN                        NaN             NaN
# 8520                  NaN                        NaN             NaN
# ...                   ...                        ...             ...
# 9995                  NaN                        NaN             NaN
# 9996                  NaN                        NaN             NaN
# 9997                  NaN                        NaN             NaN
# 9998                  NaN                        NaN             NaN
# 9999                  NaN                        NaN             NaN
#
#       post_photo_view_clicks  post_video_play_clicks  other_engagements  \
# 8516                     NaN                     NaN                NaN
# 8517                     NaN                     NaN                NaN
# 8518                     NaN                     NaN                NaN
# 8519                     NaN                     NaN                NaN
# 8520                     NaN                     NaN                NaN
# ...                      ...                     ...                ...
# 9995                     NaN                     NaN                NaN
# 9996                     NaN                     NaN                NaN
# 9997                     NaN                     NaN                NaN
# 9998                     NaN                     NaN                NaN
# 9999                     NaN                     NaN                NaN
#
#       answers  app_engagements  app_install_attempts  app_opens  \
# 8516      NaN              NaN                   NaN        NaN
# 8517      NaN              NaN                   NaN        NaN
# 8518      NaN              NaN                   NaN        NaN
# 8519      NaN              NaN                   NaN        NaN
# 8520      NaN              NaN                   NaN        NaN
# ...       ...              ...                   ...        ...
# 9995      NaN              NaN                   NaN        NaN
# 9996      NaN              NaN                   NaN        NaN
# 9997      NaN              NaN                   NaN        NaN
# 9998      NaN              NaN                   NaN        NaN
# 9999      NaN              NaN                   NaN        NaN
#
#       follows_from_post  unfollows_from_post  negative_feedback  \
# 8516                NaN                  NaN                NaN
# 8517                NaN                  NaN                NaN
# 8518                NaN                  NaN                NaN
# 8519                NaN                  NaN                NaN
# 8520                NaN                  NaN                NaN
# ...                 ...                  ...                ...
# 9995                NaN                  NaN                NaN
# 9996                NaN                  NaN                NaN
# 9997                NaN                  NaN                NaN
# 9998                NaN                  NaN                NaN
# 9999                NaN                  NaN                NaN
#
#       bit.ly_link_clicks  engaged_users  engaged_fans  \
# 8516                 NaN            NaN           NaN
# 8517                 NaN            NaN           NaN
# 8518                 NaN            NaN           NaN
# 8519                 NaN            NaN           NaN
# 8520                 NaN            NaN           NaN
# ...                  ...            ...           ...
# 9995                 NaN            NaN           NaN
# 9996                 NaN            NaN           NaN
# 9997                 NaN            NaN           NaN
# 9998                 NaN            NaN           NaN
# 9999                 NaN            NaN           NaN
#
#       users_talking_about_this  unique_reactions  unique_comments  \
# 8516                       NaN               NaN              NaN
# 8517                       NaN               NaN              NaN
# 8518                       NaN               NaN              NaN
# 8519                       NaN               NaN              NaN
# 8520                       NaN               NaN              NaN
# ...                        ...               ...              ...
# 9995                       NaN               NaN              NaN
# 9996                       NaN               NaN              NaN
# 9997                       NaN               NaN              NaN
# 9998                       NaN               NaN              NaN
# 9999                       NaN               NaN              NaN
#
#       unique_shares  unique_answers  unique_post_clicks  \
# 8516            NaN             NaN                 NaN
# 8517            NaN             NaN                 NaN
# 8518            NaN             NaN                 NaN
# 8519            NaN             NaN                 NaN
# 8520            NaN             NaN                 NaN
# ...             ...             ...                 ...
# 9995            NaN             NaN                 NaN
# 9996            NaN             NaN                 NaN
# 9997            NaN             NaN                 NaN
# 9998            NaN             NaN                 NaN
# 9999            NaN             NaN                 NaN
#
#       unique_post_link_clicks  unique_post_photo_view_clicks  \
# 8516                      NaN                            NaN
# 8517                      NaN                            NaN
# 8518                      NaN                            NaN
# 8519                      NaN                            NaN
# 8520                      NaN                            NaN
# ...                       ...                            ...
# 9995                      NaN                            NaN
# 9996                      NaN                            NaN
# 9997                      NaN                            NaN
# 9998                      NaN                            NaN
# 9999                      NaN                            NaN
#
#       unique_post_video_play_clicks  unique_other_post_clicks  \
# 8516                            NaN                       NaN
# 8517                            NaN                       NaN
# 8517                      NaN                       NaN
# 8518                      NaN                       NaN
# 8519                      NaN                       NaN
# 8520                      NaN                       NaN
# ...                       ...                       ...
# 9995                      NaN                       NaN
# 9996                      NaN                       NaN
# 9997                      NaN                       NaN
# 9998                      NaN                       NaN
# 9999                      NaN                       NaN
#
#       paid_full_video_views  autoplay_video_views  click_to_play_video_views  \
# 8516                    NaN                   NaN                        NaN
# 8517                    NaN                   NaN                        NaN
# 8518                    NaN                   NaN                        NaN
# 8519                    NaN                   NaN                        NaN
# 8520                    NaN                   NaN                        NaN
# ...                     ...                   ...                        ...
# 9995                    NaN                   NaN                        NaN
# 9996                    NaN                   NaN                        NaN
# 9997                    NaN                   NaN                        NaN
# 9998                    NaN                   NaN                        NaN
# 9999                    NaN                   NaN                        NaN
#
#       sound_on_video_views  sound_off_video_views  10_second_video_views  \
# 8516                   NaN                    NaN                    NaN
# 8517                   NaN                    NaN                    NaN
# 8518                   NaN                    NaN                    NaN
# 8519                   NaN                    NaN                    NaN
# 8520                   NaN                    NaN                    NaN
# ...                    ...                    ...                    ...
# 9995                   NaN                    NaN                    NaN
# 9996                   NaN                    NaN                    NaN
# 9997                   NaN                    NaN                    NaN
# 9998                   NaN                    NaN                    NaN
# 9999                   NaN                    NaN                    NaN
#
#       organic_10_second_video_views  paid_10_second_video_views  \
# 8516                            NaN                         NaN
# 8517                            NaN                         NaN
# 8518                            NaN                         NaN
# 8519                            NaN                         NaN
# 8520                            NaN                         NaN
# ...                             ...                         ...
# 9995                            NaN                         NaN
# 9996                            NaN                         NaN
# 9997                            NaN                         NaN
# 9998                            NaN                         NaN
# 9999                            NaN                         NaN
#
#       autoplay_10_second_video_views  click_to_play_10_second_video_views  \
# 8516                             NaN                                  NaN
# 8517                             NaN                                  NaN
# 8518                             NaN                                  NaN
# 8519                             NaN                                  NaN
# 8520                             NaN                                  NaN
# ...                              ...                                  ...
# 9995                             NaN                                  NaN
# 9996                             NaN                                  NaN
# 9997                             NaN                                  NaN
# 9998                             NaN                                  NaN
# 9999                             NaN                                  NaN
#
#       sound_on_10_second_video_views  sound_off_10_second_video_views  \
# 8516                             NaN                              NaN
# 8517                             NaN                              NaN
# 8518                             NaN                              NaN
# 8519                             NaN                              NaN
# 8520                             NaN                              NaN
# ...                              ...                              ...
# 9995                             NaN                              NaN
# 9996                             NaN                              NaN
# 9997                             NaN                              NaN
# 9998                             NaN                              NaN
# 9999                             NaN                              NaN
#
#       autoplay_partial_video_views  click_to_play_partial_video_views  \
# 8516                           NaN                                NaN
# 8517                           NaN                                NaN
# 8518                           NaN                                NaN
# 8519                           NaN                                NaN
# 8520                           NaN                                NaN
# ...                            ...                                ...
# 9995                           NaN                                NaN
# 9996                           NaN                                NaN
# 9997                           NaN                                NaN
# 9998                           NaN                                NaN
# 9999                           NaN                                NaN
#
#       autoplay_full_video_views  click_to_play_full_video_views  \
# 8516                        NaN                             NaN
# 8517                        NaN                             NaN
# 8518                        NaN                             NaN
# 8519                        NaN                             NaN
# 8520                        NaN                             NaN
# ...                         ...                             ...
# 9995                        NaN                             NaN
# 9996                        NaN                             NaN
# 9997                        NaN                             NaN
# 9998                        NaN                             NaN
# 9999                        NaN                             NaN
#
#       95%_video_views  organic_95%_video_views  paid_95%_video_views  \
# 8516              NaN                      NaN                   NaN
# 8517              NaN                      NaN                   NaN
# 8518              NaN                      NaN                   NaN
# 8519              NaN                      NaN                   NaN
# 8520              NaN                      NaN                   NaN
# ...               ...                      ...                   ...
# 9995              NaN                      NaN                   NaN
# 9996              NaN                      NaN                   NaN
# 9997              NaN                      NaN                   NaN
# 9998              NaN                      NaN                   NaN
# 9999              NaN                      NaN                   NaN
#
#       video_length_seconds  average_video_time_watched_seconds  \
# 8516                   NaN                                 NaN
# 8517                   NaN                                 NaN
# 8518                   NaN                                 NaN
# 8519                   NaN                                 NaN
# 8520                   NaN                                 NaN
# ...                    ...                                 ...
# 9995                   NaN                                 NaN
# 9996                   NaN                                 NaN
# 9997                   NaN                                 NaN
# 9998                   NaN                                 NaN
# 9999                   NaN                                 NaN
#
#       video_view_time_seconds  organic_video_view_time_seconds  \
# 8516                      NaN                              NaN
# 8517                      NaN                              NaN
# 8518                      NaN                              NaN
# 8519                      NaN                              NaN
# 8520                      NaN                              NaN
# ...                       ...                              ...
# 9995                      NaN                              NaN
# 9996                      NaN                              NaN
# 9997                      NaN                              NaN
# 9998                      NaN                              NaN
# 9999                      NaN                              NaN
#
#       paid_video_view_time_seconds  unique_video_views  \
# 8516                           NaN                 NaN
# 8517                           NaN                 NaN
# 8518                           NaN                 NaN
# 8519                           NaN                 NaN
# 8520                           NaN                 NaN
# ...                            ...                 ...
# 9995                           NaN                 NaN
# 9996                           NaN                 NaN
# 9997                           NaN                 NaN
# 9998                           NaN                 NaN
# 9999                           NaN                 NaN
#
#       unique_organic_video_views  unique_paid_video_views  \
# 8516                         NaN                      NaN
# 8517                         NaN                      NaN
# 8518                         NaN                      NaN
# 8519                         NaN                      NaN
# 8520                         NaN                      NaN
# ...                          ...                      ...
# 9995                         NaN                      NaN
# 9996                         NaN                      NaN
# 9997                         NaN                      NaN
# 9998                         NaN                      NaN
# 9999                         NaN                      NaN
#
#       unique_10_second_video_views  unique_full_video_views  \
# 8516                           NaN                      NaN
# 8517                           NaN                      NaN
# 8518                           NaN                      NaN
# 8519                           NaN                      NaN
# 8520                           NaN                      NaN
# ...                            ...                      ...
# 9995                           NaN                      NaN
# 9996                           NaN                      NaN
# 9997                           NaN                      NaN
# 9998                           NaN                      NaN
# 9999                           NaN                      NaN
#
#       unique_organic_95%_video_views  unique_paid_95%_video_views  \
# 8516                             NaN                          NaN
# 8517                             NaN                          NaN
# 8518                             NaN                          NaN
# 8519                             NaN                          NaN
# 8520                             NaN                          NaN
# ...                              ...                          ...
# 9995                             NaN                          NaN
# 9996                             NaN                          NaN
# 9997                             NaN                          NaN
# 9998                             NaN                          NaN
# 9999                             NaN                          NaN
#
#       video_ad_break_ad_impressions  video_ad_break_ad_earnings  \
# 8516                            NaN                         NaN
# 8517                            NaN                         NaN
# 8518                            NaN                         NaN
# 8519                            NaN                         NaN
# 8520                            NaN                         NaN
# ...                             ...                         ...
# 9995                            NaN                         NaN
# 9996                            NaN                         NaN
# 9997                            NaN                         NaN
# 9998                            NaN                         NaN
# 9999                            NaN                         NaN
#
#       video_ad_break_ad_cost_per_impression_cpm  youtube_premium_views  \
# 8516                                        NaN                    NaN
# 8517                                        NaN                    NaN
# 8518                                        NaN                    NaN
# 8519                                        NaN                    NaN
# 8520                                        NaN                    NaN
# ...                                         ...                    ...
# 9995                                        NaN                    NaN
# 9996                                        NaN                    NaN
# 9997                                        NaN                    NaN
# 9998                                        NaN                    NaN
# 9999                                        NaN                    NaN
#
#       estimated_minutes_watched  estimated_premium_minutes_watched  \
# 8516                        NaN                                NaN
# 8517                        NaN                                NaN
# 8518                        NaN                                NaN
# 8519                        NaN                                NaN
# 8520                        NaN                                NaN
# ...                         ...                                ...
# 9995                        NaN                                NaN
# 9996                        NaN                                NaN
# 9997                        NaN                                NaN
# 9998                        NaN                                NaN
# 9999                        NaN                                NaN
#
#       story_taps_back  story_taps_forward  story_exits  story_replies  \
# 8516              NaN                 NaN          NaN            NaN
# 8517              NaN                 NaN          NaN            NaN
# 8518              NaN                 NaN          NaN            NaN
# 8519              NaN                 NaN          NaN            NaN
# 8520              NaN                 NaN          NaN            NaN
# ...               ...                 ...          ...            ...
# 9995              NaN                 NaN          NaN            NaN
# 9996              NaN                 NaN          NaN            NaN
# 9997              NaN                 NaN          NaN            NaN
# 9998              NaN                 NaN          NaN            NaN
# 9999              NaN                 NaN          NaN            NaN
#
#       video_added_to_playlists  subscribers_lost_from_video  \
# 8516                       NaN                          NaN
# 8517                       NaN                          NaN
# 8518                       NaN                          NaN
# 8519                       NaN                          NaN
# 8520                       NaN                          NaN
# ...                        ...                          ...
# 9995                       NaN                          NaN
# 9996                       NaN                          NaN
# 9997                       NaN                          NaN
# 9998                       NaN                          NaN
# 9999                       NaN                          NaN
#
#       video_removed_from_playlists  annotation_impressions  \
# 8516                           NaN                     NaN
# 8517                           NaN                     NaN
# 8518                           NaN                     NaN
# 8519                           NaN                     NaN
# 8520                           NaN                     NaN
# ...                            ...                     ...
# 9995                           NaN                     NaN
# 9996                           NaN                     NaN
# 9997                           NaN                     NaN
# 9998                           NaN                     NaN
# 9999                           NaN                     NaN
#
#       annotation_clickable_impressions  annotation_closable_impressions  \
# 8516                               NaN                              NaN
# 8517                               NaN                              NaN
# 8518                               NaN                              NaN
# 8519                               NaN                              NaN
# 8520                               NaN                              NaN
# ...                                ...                              ...
# 9995                               NaN                              NaN
# 9996                               NaN                              NaN
# 9997                               NaN                              NaN
# 9998                               NaN                              NaN
# 9999                               NaN                              NaN
#
#       annotation_closes  card_impressions  card_teaser_impressions  \
# 8516                NaN               NaN                      NaN
# 8517                NaN               NaN                      NaN
# 8518                NaN               NaN                      NaN
# 8519                NaN               NaN                      NaN
# 8520                NaN               NaN                      NaN
# ...                 ...               ...                      ...
# 9995                NaN               NaN                      NaN
# 9996                NaN               NaN                      NaN
# 9997                NaN               NaN                      NaN
# 9998                NaN               NaN                      NaN
# 9999                NaN               NaN                      NaN
#
#       card_teaser_clicks  poll_votes  \
# 8516                 NaN         NaN
# 8517                 NaN         NaN
# 8518                 NaN         NaN
# 8519                 NaN         NaN
# 8520                 NaN         NaN
# ...                  ...         ...
# 9995                 NaN         NaN
# 9996                 NaN         NaN
# 9997                 NaN         NaN
# 9998                 NaN         NaN
# 9999                 NaN         NaN
#
#                                                    tags
# 8516                     BCC, Enterprise Academy Monday
# 8517       Insurance Limited Posts, Weekly Wealth Posts
# 8518  CHNW Mass Retail, Cybersecurity Webinar, Weekl...
# 8519                                                NaN
# 8520                                  BCC, Blue Blossom
# ...                                                 ...
# 9995                                                NaN
# 9996                                                NaN
# 9997                                                NaN
# 9998                                                NaN
# 9999                                                NaN
#
# [1484 rows x 147 columns]

# %% [markdown]
# Observing the frames above, for both categorical and numerical columns dropping those missing values doesn't make much sense. For the numerical columns however, filling with zero should be done. This will be done during EDA.

# %% [markdown]
# #### Remove duplicates

# %%
# check for and remove duplicates
if df_test.duplicated().sum() > 0:
    df_test.drop_duplicates(inplace=True)

# %% [markdown]
# #### Remove excessive whitespace from string columns

# %%
for column in df_test.columns:
    if df_test[column].dtype == 'object':
        df_test[column] = df_test[column].str.strip()

# %% [markdown]
# #### Define function and Save clean data to a csv file

# %%
def clean_data(*dataframes):
    """
    Cleans and standardizes a list of DataFrames and saves them to CSV files.

    Parameters:
    *dataframes (pd.DataFrame): Variable number of input DataFrames to be cleaned.

    Notes:
    - Column names are converted to lowercase and special characters are replaced with underscores.
    - The 'date' column is converted to a datetime format.
    - Columns containing numeric strings are converted to float, handling comma and percent formatting.
    - 'sent_by' column is corrected by replacing white spaces with 'admin'.
    - Duplicate rows are dropped if any exist.
    - Each cleaned DataFrame is saved to a separate CSV file with a unique name.
    """
    
    for i, dataframe in enumerate(dataframes, 1):
        # standardize column names
        dataframe.columns = dataframe.columns.str.lower()\
        .str.replace('-', '_')\
        .str.replace(' ', '_')\
        .str.replace('(', '')\
        .str.replace(')', '')
        
        # convert date column to datetime
        dataframe['date'] = pd.to_datetime(dataframe['date'], format='%m/%d/%Y %I:%M %p')
       
        # convert string columns with numbers to float
        for column in dataframe.columns:
            if dataframe[column].dtype == 'object':
                if dataframe[column].str.isnumeric().any():
                    dataframe[column] = dataframe[column].str.replace(',','').astype(float)
                elif 'per' in dataframe[column].name:
                    dataframe[column] = dataframe[column].str.replace(',','').str.replace('%','').astype(float)
                elif 'rate' in dataframe[column].name:
                    dataframe[column] = dataframe[column].str.replace(',','').str.replace('%','').astype(float)
        
        # replace white space in sent_by with admin
        dataframe['sent_by'] = dataframe['sent_by'].replace(' ', 'admin')
        
        # drop duplicates if any exist
        if dataframe.duplicated().sum() > 0:
            dataframe.drop_duplicates(inplace=True)
        
        # remove trailing whitespace from string columns
        for column in dataframe.columns:
            if dataframe[column].dtype == 'object':
                dataframe[column] = dataframe[column].str.strip()
        
        # Save the cleaned DataFrame to a CSV file with a unique name
        csv_filename = f"../data/processed/Cleaned-Post Performance (Stanbic IBTC) January 1, 2013 - July 13, 2023_{dataframe['network'].values[0]}.csv"
        dataframe.to_csv(csv_filename, index=False)

# %%
clean_data(df_insta, df_lnkd, df_twit, df_fbk)
